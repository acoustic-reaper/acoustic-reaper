# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding='latin-1')
dataset.describe(include='all')
dataset.columns
# Out:
# Index(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element',
#        'Unit', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018'],
#       dtype='object')

# %%
dataset.shape
# Out:
# (60943, 12)

# %%
x = dataset.groupby('Area')['Y2017'].sum()
mx = x.max()
for i in range(len(x)):
    if x[i] == mx:
        print(x.index[i])
        break
# Out:
# Nigeria

# %%
round(dataset['Y2017'].mean(), 2), round(dataset['Y2017'].std(), 2)
# Out:
# (140.92, 1671.86)

# %%
seventh_lowest_sum = x.sort_values()[6]
for i in range(len(x)):
    if (x[i] == seventh_lowest_sum):
        print(x.index[i])
# Out:
# Guinea-Bissau

# %%
dataset.groupby('Item')['Y2015'].sum(), dataset.groupby('Item')['Y2018'].sum()
# Out:
# (Item
#  Alcohol, Non-Food        2180.00
#  Alcoholic Beverages     98783.72
#  Animal Products         11811.73
#  Animal fats            200675.72
#  Apples and products     10559.15
#                           ...
#  Vegetables, Other      158104.08
#  Vegetal Products       107064.17
#  Wheat and products     234710.51
#  Wine                     4251.81
#  Yams                   203151.78
#  Name: Y2015, Length: 119, dtype: float64,
#  Item
#  Alcohol, Non-Food        2293.00
#  Alcoholic Beverages     97847.27
#  Animal Products         11578.61
#  Animal fats            269648.27
#  Apples and products      9640.51
#                           ...
#  Vegetables, Other      163987.21
#  Vegetal Products       107775.39
#  Wheat and products     242645.19
#  Wine                     4039.32
#  Yams                   221272.09
#  Name: Y2018, Length: 119, dtype: float64)

# %%
dataset.groupby('Element').sum()
# Out:
#                                         Area Code
# Element
# Domestic supply quantity                   708993  \
# Export Quantity                            599910
# Fat supply quantity (g/capita/day)         675050
# Feed                                       176272
# Food                                       663295
# Food supply (kcal/capita/day)              674057
# Food supply quantity (kg/capita/yr)        658446
# Import Quantity                            688174
# Losses                                     274353
# Other uses (non-food)                      235554
# Processing                                 271940
# Production                                 526751
# Protein supply quantity (g/capita/day)     675050
# Residuals                                  623271
# Seed                                       103537
# Stock Variation                            571566
# Total Population - Both sexes                6020
# ...

# %%
x = dataset.isna().sum().at['Y2014']
x, round(x / len(dataset) * 100, 3)
# Out:
# (1589, 2.607)

# %%
len(dataset.groupby('Area')['Item'].max())
# Out:
# 49

# %%
dataset.groupby('Element')['Y2017'].sum()
# Out:
# Element
# Domestic supply quantity                  2088198.10
# Export Quantity                            182338.80
# Fat supply quantity (g/capita/day)          10253.84
# Feed                                       223705.68
# Food                                      1258888.28
# Food supply (kcal/capita/day)              454681.00
# Food supply quantity (kg/capita/yr)         48690.04
# Import Quantity                            294559.09
# Losses                                     160614.00
# Other uses (non-food)                       91645.97
# Processing                                 292836.00
# Production                                2030056.89
# Protein supply quantity (g/capita/day)      11842.45
# Residuals                                   35500.00
# Seed                                        24870.14
# Stock Variation                             54316.91
# Total Population - Both sexes             1112641.00
# Tourist consumption                            91.00
# ...

# %%
y = dataset.groupby('Item')['Y2015'].sum()
y.to_csv('anything.csv')

# %%
dataset['Element Code'].corr(dataset['Y2014']), dataset['Element Code'].corr(dataset['Y2015']), dataset['Element Code'].corr(dataset['Y2016']), dataset['Element Code'].corr(dataset['Y2017'])
# Out:
# (0.024456819495221754,
#  0.023889199301639942,
#  0.02344399758496145,
#  0.024254007760045777)
